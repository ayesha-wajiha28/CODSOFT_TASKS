# %%
import pandas as pd

df.to_csv(r"C:\Users\Administrator\Desktop\cleaned_train.csv", index=False)

print("\nCleaned dataset successfully saved in Desktop as 'cleaned_train.csv'!")

print("--- Data-vin Mudhal 5 Rows ---")
print(df.head())

print("\n--- Data Structure & Information ---")
df.info()

print("\n--- Duplicates Remove Panradhu ---")
df = df.drop_duplicates()

print("\n--- Missing Values Count ---")
print(df.isnull().sum())

print("\n--- Missing Values Clean Panradhu ---")
df = df.dropna()

print("\n--- Cleaned Data Summary ---")
df.info()

df.to_csv("cleaned_train.csv", index=False)
print("\nCleaned dataset successfully saved as 'cleaned_train.csv'!")
# Out:
# Cleaned dataset successfully saved in Desktop as 'cleaned_train.csv'!
# --- Data-vin Mudhal 5 Rows ---
#     PassengerId  Pclass                                               Name  \
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918       1                       Ostby, Miss. Helene Ragnhild
# 28          920       1                            Brady, Mr. John Bertram
#
#        Sex   Age  SibSp  Parch       Ticket      Fare            Cabin
# 12  female  23.0      1      0        21228   82.2667              B45
# 14  female  47.0      1      0  W.E.P. 5734   61.1750              E31
# 24  female  48.0      1      3     PC 17608  262.3750  B57 B59 B63 B66
# 26  female  22.0      0      1       113509   61.9792              B36
# ...
